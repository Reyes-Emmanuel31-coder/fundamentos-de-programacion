# %% [markdown]
# <a href="https://colab.research.google.com/github/Reyes-Emmanuel31-coder/fundamentos-de-programacion/blob/main/Programa_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
X = "Carlos"
variableBooleana=True
print("Hola",x, X,"X")
# Out:
# Hola Carlos
