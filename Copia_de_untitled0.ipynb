# %% [markdown]
# <a href="https://colab.research.google.com/github/Reyes-Emmanuel31-coder/fundamentos-de-programacion/blob/main/Copia_de_untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
    print(f"El numero {numero1} es mayor que {numero2}")
else:
    print(f"El numero {numero2} es mayor que {numero1}")
# Out:
# El numero 40 es mayor que 20

# %%
edad= int(input("Dame tu edad"))
if edad <=10:
  print("Eres un niño")
elif edad <=18:
  print("Eres un adolescente")
elif edad <=30:
  print("Eres un joven adulto joven")
elif edad <= 65:
  print("Eres un adulto")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad15
# Eres un adolescente

# %%
base= input("Dame la base del triangulo")
altura = input("Dame la altura del triangulo")
area=(int(base)*int(altura))/2
print("el area del triangulo es",area)
# Out:
# Dame la base del triangulo10
# Dame la altura del triangulo15
# el area del triangulo es 75.0

# %%
z=10
a="hola"
print(z * a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
edad = int(input("Dame tu edad"))
if edad <=65:
  print("Eres un adulto")
  if edad <= 30:
      print("Eres un adulto joven")
  elif  edad <=18:
      print("Eres un adolesente")
  elif  edad <=10:
        print("Eres un niño")
  else:
          print("Eres un adulto mayor")
# Out:
# Dame tu edad38
# Eres un adulto
# Eres un adulto mayor
